# %% [markdown]
# # Module 37 — Computer Use & Always-On AI Teammates
#
# Study agents that interact with graphical or browser environments and operate continuously. Build the safety architecture before enabling powerful actions.

# %% [markdown]
# ## Computer-use control model
# Observe screen/state → interpret → propose action → policy check → approval if required → execute → verify → screenshot/state evidence → continue/stop.

# %%
class MockComputer:
    def __init__(self): self.log=[]
    def click(self,x,y): self.log.append(('click',x,y)); return {'ok':True}
    def screenshot(self): return {'screen':'mock'}
pc=MockComputer(); print(pc.screenshot())

# %% [markdown]
# ## Lab 1 — Environment abstraction
# Create a mock desktop/browser interface with screenshot, click, type, scroll and navigation actions.

# %% [markdown]
# ## Lab 2 — Action grounding
# Map model proposals to concrete UI targets. Reject ambiguous or stale targets.

# %% [markdown]
# ## Lab 3 — Safe action policy
# Classify actions as read-only, reversible, sensitive or consequential. Apply approval gates.

# %% [markdown]
# ## Lab 4 — Browser automation
# Build a synthetic website and complete a multi-step workflow without real credentials.

# %% [markdown]
# ## Lab 5 — Verification
# After each action, verify visible state rather than assuming the click succeeded.

# %% [markdown]
# ## Lab 6 — Stale screen defense
# Change the UI between observation and action. Detect stale state and re-observe.

# %% [markdown]
# ## Lab 7 — Prompt injection on webpages
# Place hostile instructions in page content. Treat them as untrusted data rather than agent policy.

# %% [markdown]
# ## Lab 8 — Credential boundary
# Design a secret broker so the model never receives reusable credentials in its context.

# %% [markdown]
# ## Lab 9 — Always-on scheduling
# Build wake/sleep jobs, health checks, budgets and cancellation for continuous workers.

# %% [markdown]
# ## Lab 10 — Human teammate mode
# Define when the agent acts autonomously, asks for confirmation or escalates to a human.

# %% [markdown]
# ## Lab 11 — Activity audit
# Record screenshots/state references, actions, policy decisions, approvals and verification results.

# %% [markdown]
# ## Lab 12 — Failure injection
# Inject UI changes, network failures, duplicate clicks, modal dialogs, timeouts and permission errors.

# %% [markdown]
# ## Failure-first exercises
# Wrong click, stale screen, hostile webpage, secret exposure, accidental destructive action, duplicate submission, infinite navigation, unattended approval and worker crash.

# %% [markdown]
# ## 15 extension exercises
# Add browser tabs, visual grounding, DOM grounding, action confidence, screenshot diffing, approval workflows, secret brokering, sandboxing, action rollback, idempotent form submission, job scheduling, interruption handling, anomaly detection, audit replay and computer-use red-team benchmarks.

# %% [markdown]
# ## Gold challenge
# Build an always-on enterprise digital worker operating in a synthetic browser environment. It must complete useful workflows while enforcing action policy, human approval, secret isolation, verification, budgets, durable recovery and auditability.
