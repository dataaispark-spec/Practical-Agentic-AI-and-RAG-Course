# %% [markdown]
# # Module 28 — Responsible AI + Security: AI Governance Layer
#
# Build executable governance: risk classification, policy enforcement, data/model eligibility, human oversight, audit evidence and incident controls.

# %%
from dataclasses import dataclass
@dataclass
class UseCase:
    risk:int; data:str; model:str; tool:str|None=None; human:bool=False
models={'model-a'}; tools={'search'}

# %% [markdown]
# ## Lab 1 — Use-case registry
# Create owners, purposes, data classes, risk tiers and approval states.

# %% [markdown]
# ## Lab 2 — Risk classification
# Classify low, controlled, high-impact and restricted workflows. Add an explicit review state for uncertainty.

# %% [markdown]
# ## Lab 3 — Policy engine
# Implement allow/deny/approval decisions. Verify that model output cannot override a deny decision.

# %% [markdown]
# ## Lab 4 — Data gate
# Block models that are not approved for the input data classification.

# %% [markdown]
# ## Lab 5 — Model/vendor eligibility
# Filter by capability, privacy, geography, contract status and risk tier.

# %% [markdown]
# ## Lab 6 — Human oversight
# Require exact approval for high-impact actions and test replay/action mutation.

# %% [markdown]
# ## Lab 7 — Audit evidence
# Record policy version, inputs/classifications, decision, reason, approver and action hash.

# %% [markdown]
# ## Lab 8 — Exceptions
# Create scoped, owned and time-limited exceptions. Test expiry.

# %% [markdown]
# ## Lab 9 — Incident workflow
# Map violations to severity, containment, owner, remediation and regression tests.

# %% [markdown]
# ## Lab 10 — Agent governance
# Apply policy to tools, memory, MCP servers, autonomous loops and computer-use actions.

# %% [markdown]
# ## Lab 11 — Continuous monitoring
# Build signals for policy violations, unsafe actions, approval anomalies and drift.

# %% [markdown]
# ## Lab 12 — Third-party model review
# Build an intake checklist for security, privacy, residency, reliability, evaluation and cost.

# %% [markdown]
# ## Lab 13 — Red team
# Attack prompt/tool injection, privilege escalation, data exfiltration and approval bypass boundaries.

# %% [markdown]
# ## Lab 14 — Governance regression
# Convert every material incident into a permanent automated test.

# %% [markdown]
# ## Lab 15 — Release certification
# Generate a release packet containing model/version, evaluations, security findings, policy status, residual risk and rollback plan.

# %% [markdown]
# # Failure-first exercises
# 1. Model overrides policy.
# 2. Restricted data reaches an unapproved model.
# 3. Approval is replayed for a modified action.
# 4. Expired exception remains active.
# 5. Audit event disappears.
# 6. Tenant boundary is crossed.
# 7. Tool output is trusted as policy.
# 8. High-impact action bypasses human review.
# 9. Safe low-risk work is over-blocked.
# 10. Model update ships without re-evaluation.
# 11. Policy changes without version evidence.
# 12. Agent delegates to an unapproved tool.
# 13. Sensitive memory persists beyond purpose.
# 14. Monitoring misses a violation.
# 15. Incident closes without a regression test.

# %% [markdown]
# # Gold challenge
# Build the AegisAI Governance Control Plane and integrate security, observability, evaluation and cost controls from Modules 18, 25–27.
