# %% [markdown]
# # Module 29 — Deployment + CI/CD
#
# Build a release pipeline for AI systems. The key idea: an AI release includes more than application code — model, prompt, retrieval, tools and policy can all change behavior.

# %% [markdown]
# ## Lab 1 — Release manifest
# Capture application, artifact, model, prompt, retrieval, policy and evaluation versions.

# %%
manifest={'app':'1.0','artifact':'sha256:abc','model':'m1','prompt':'p1','retrieval':'r1','policy':'pol1','evaluation':'e1'}
assert all(manifest.values())
print(manifest)

# %% [markdown]
# ## Lab 2 — CI gates
# Build format → tests → security → evaluation → governance gates. A critical block must prevent promotion.

# %% [markdown]
# ## Lab 3 — Configuration and secrets
# Separate configuration from source and design a secret scanner. Never commit credentials or bake them into images.

# %% [markdown]
# ## Lab 4 — Health and readiness
# Distinguish process liveness from dependency readiness and test failure behavior.

# %% [markdown]
# ## Lab 5 — Immutable artifacts
# Build once and promote the same artifact digest through environments.

# %% [markdown]
# ## Lab 6 — Integration tests
# Use test doubles for model, RAG, tool and policy boundaries.

# %% [markdown]
# ## Lab 7 — Evaluation gate
# Connect Module 26 and block releases below quality/safety thresholds.

# %% [markdown]
# ## Lab 8 — Governance gate
# Connect Module 28 and reject unauthorized model, data or capability configurations.

# %% [markdown]
# ## Lab 9 — Shadow deployment
# Compare candidate and incumbent without changing user-visible results.

# %% [markdown]
# ## Lab 10 — Canary
# Route controlled traffic to a candidate and define automatic abort thresholds.

# %% [markdown]
# ## Lab 11 — Rollback
# Test independent rollback of application, model, prompt, retrieval or policy versions.

# %% [markdown]
# ## Lab 12 — State migration
# Design backward-compatible schema changes and restart-safe migrations.

# %% [markdown]
# ## Lab 13 — Incident drill
# Inject latency, model outage, policy regression, tool failure and cost explosion.

# %% [markdown]
# ## Lab 14 — SLO review
# Track availability, p95 latency, error rate, task success, safety, cost/success and recovery time.

# %% [markdown]
# ## Lab 15 — Production certification
# Produce an auditable release packet and demonstrate rollback of a deliberately bad release.

# %% [markdown]
# # 15 extension exercises
# 1. Manifest validator.
# 2. Gate aggregator.
# 3. Secret scanner.
# 4. Readiness checker.
# 5. Container hardening checklist.
# 6. Integration test harness.
# 7. Evaluation release gate.
# 8. Governance release gate.
# 9. Shadow comparator.
# 10. Canary controller.
# 11. Rollback planner.
# 12. Migration compatibility checker.
# 13. Incident runbook.
# 14. SLO dashboard.
# 15. Complete AegisAI production pipeline.

# %% [markdown]
# # Failure-first challenge
# Change a model or policy without updating its release identity, trigger a regression, detect it through evaluation/telemetry, abort the rollout, restore the correct version and document the incident.
