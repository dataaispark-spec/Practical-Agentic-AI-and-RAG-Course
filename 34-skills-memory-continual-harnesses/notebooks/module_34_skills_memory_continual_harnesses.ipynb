# %% [markdown]
# # Module 34 — Skills, Memory & Continual Harnesses
#
# Build agents that improve through reusable skills, persistent memory and evidence-driven refinement — without allowing self-modification to bypass evaluation or security controls.

# %% [markdown]
# ## Mental model
# Experience → trajectory → extract candidate skill/memory → validate → evaluate → approve → version → deploy → monitor → rollback.

# %%
from dataclasses import dataclass
@dataclass
class Memory:
    key:str; value:str; source:str; confidence:float; version:int=1
m=Memory('preferred_format','tables','user_request',.95)
print(m)

# %% [markdown]
# ## Lab 1 — Memory taxonomy
# Separate working, episodic, semantic, procedural and user memory. Define retention and provenance for each.

# %% [markdown]
# ## Lab 2 — Provenance
# Every persistent fact must have source, timestamp, confidence and ownership metadata.

# %% [markdown]
# ## Lab 3 — Contradictions
# Store competing memories and implement supersession instead of silently overwriting evidence.

# %% [markdown]
# ## Lab 4 — Skill extraction
# Extract a candidate procedure from successful trajectories. Keep candidate skills separate from trusted skills.

# %% [markdown]
# ## Lab 5 — Skill validation
# Run a skill against a benchmark, adversarial cases and regression tests before promotion.

# %% [markdown]
# ## Lab 6 — Versioning
# Version skills, memory schemas and harness policies. Support rollback.

# %% [markdown]
# ## Lab 7 — Memory poisoning
# Inject malicious or incorrect memories. Test trust, source verification and tenant isolation.

# %% [markdown]
# ## Lab 8 — Continual improvement loop
# Use failure evidence to propose improvements, but require deterministic gates before activation.

# %% [markdown]
# ## Lab 9 — User model
# Learn stable preferences only from authorized evidence. Test accidental inference and stale preferences.

# %% [markdown]
# ## Lab 10 — Skill routing
# Select among versioned skills by capability, context and policy. Avoid skill explosion.

# %% [markdown]
# ## Lab 11 — Expiry and forgetting
# Implement TTL, revocation and deletion semantics for memories that should not persist indefinitely.

# %% [markdown]
# ## Lab 12 — Continual benchmark
# Compare baseline versus improved harness using fixed cases, safety tests, cost and task success.

# %% [markdown]
# ## Failure-first exercises
# Poisoned memory, false skill extraction, benchmark overfitting, skill privilege escalation, stale preference, tenant leakage, silent overwrite, regression after learning, unbounded memory and unsafe self-modification.

# %% [markdown]
# ## 15 extension exercises
# Build semantic retrieval over memory, contradiction graphs, skill confidence, skill dependency DAGs, skill sandboxing, memory TTL, selective forgetting, human approval, automatic regression generation, trajectory clustering, failure-to-skill mining, version rollback, memory access policies, tenant-scoped learning and continual evaluation.

# %% [markdown]
# ## Gold challenge
# Build a self-improving AegisAI subsystem that can learn reusable skills and memories from trajectories while proving that every promoted change passed evaluation, security and governance gates.
