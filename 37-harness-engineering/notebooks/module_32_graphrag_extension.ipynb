# %% [markdown]
# # Module 37 — Legacy Notebook Alias
#
# This file is retained only for compatibility with older course links. The canonical Module 37 notebook is `module_37_harness_engineering.ipynb`.
#
# The course canonical map identifies `37-harness-engineering/` as Module 37 and reserves older numbering as legacy compatibility material. fileciteturn684file0L2-L2
